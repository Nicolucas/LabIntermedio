# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from pylab import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Sr90 - Datos Sin Magnetos

# %% [markdown]
# #### Carga de datos...

# %%
data = loadtxt("Sr90")
phi0 = data[:,0]
R0 = data[:,1]
R1 = data[:,2]
num=shape(phi0)[0]
dataMatrix=matrix([phi0,R0,R1])
m=dataMatrix.T

col = 0
datLab=m[np.array(m[:,col].argsort(axis=0).tolist()).ravel()]

# %% [markdown]
# #### organizar datos

# %%
t = linspace(-pi/2, pi/2, num)
r0=array(datLab[:,1])
r1=array(datLab[:,2])

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1.0, 1.0], polar=True)
ax.plot(t, r0);

# %%
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1.0,1.0], polar=True)
ax.plot(t, r1);

# %%
clear

# %% [markdown]
# ### Con Magnetos a 2cm

# %%
data = loadtxt("Sr90Magneto2")
phi0 = data[:,0]
R0 = data[:,1]
R1 = data[:,2]
num=shape(phi0)[0]
dataMatrix=matrix([phi0,R0,R1])
m=dataMatrix.T

col = 0
datLab=m[np.array(m[:,col].argsort(axis=0).tolist()).ravel()]

t = linspace(-pi/2, pi/2, num)
r0=array(datLab[:,1])
r1=array(datLab[:,2])

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
ax.plot(t, r0);

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1.0, 1.0], polar=True)
ax.plot(t, r1);

# %%
clear

# %% [markdown]
# ### Con Magnetos Transpuestos

# %%
data = loadtxt("Sr90Magn2")
phi0 = data[:,0]
R0 = data[:,1]
R1 = data[:,2]
num=shape(phi0)[0]
dataMatrix=matrix([phi0,R0,R1])
m=dataMatrix.T

col = 0
datLab=m[np.array(m[:,col].argsort(axis=0).tolist()).ravel()]

t = linspace(-pi/2, pi/2, num)
r0=array(datLab[:,1])
r1=array(datLab[:,2])

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
ax.plot(t, r0);

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1.0, 1.0], polar=True)
ax.plot(t, r1);

# %%
clear

# %% [markdown]
# ### Magnets Closer

# %%
data = loadtxt("Sr90MagnClose")
phi0 = data[:,0]
R0 = data[:,1]
R1 = data[:,2]
num=shape(phi0)[0]
dataMatrix=matrix([phi0,R0,R1])
m=dataMatrix.T

col = 0
datLab=m[np.array(m[:,col].argsort(axis=0).tolist()).ravel()]

t = linspace(-pi/2, pi/2, num)
r0=array(datLab[:,1])
r1=array(datLab[:,2])

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
ax.plot(t, r0);

# %%
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, 1.0, 1.0], polar=True)
ax.plot(t, r1);
